# %% [markdown]
# # Ejecución presupuestal - Proyectos por gobiernos regionales - Provinciales - Distritales - Mes de julio 2026
#
# ### Objetivo
#
# - Determinar que gobiernos regionales del Perú esta ejecutando mejor su presupuesto de proyectos a la fecha de julio 2026.
# - Analizar que provincias de la región junín esta ejecutando mejor su presupuesto de proyectos a la fecha de julio 2026.
# - Analizar que distritos de la Provincia de Huancayo esta ejecutando mejor su presupuesto de proyectos a la fecha de julio 2026.
#
# ### Fuente de datos
#
# - [Presupuesto publico 2026](https://datosabiertos.mef.gob.pe/dataset/presupuesto-y-ejecucion-de-gasto)

# %%
# Librearias
import os

import pandas as pd
import polars as pl

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

import requests


# plt.style.use('')
plt.rcParams.update({
    'figure.figsize'    :   (12,6)      ,
    # 'axes.facecolor'    :   '#0d1117'   ,
    # 'figure.facecolor'  :   '#30363d'   ,
    'grid.linestyle'    :   '--'        ,
    'grid.alpha'        :   0.5         ,
    'font.size'         :   10          ,
})

# %%
# URL = "https://api.datosabiertos.mef.gob.pe/DatosAbiertos/v1/datastore_search"

# params = {
#     "resource_id": "d45f660d-6d14-438e-9d91-300084c9b85f",
#     "limit": 1000,
# }

# response = requests.get(URL, params=params)

# print(response.status_code)

# data = response.json()

# # miramos las claves principales
# print(data.keys()) # dict_keys(['sucess', 'result', 'records', 'next', 'help'])
# print("Registros:", len(data.get("records", [])))
# print("Total:", data.get("result", {}).get("include_total"))
# print("Next:", data.get("next"))

# %%
# # Comprobamos limites maximos
# for limit in [1000, 5000, 10000, 50000, 100000]:
    
#     params = {
#         "resource_id": "d45f660d-6d14-438e-9d91-300084c9b85f",
#         "limit": limit, # Cuantos registros quiero por peticion
#         "offset": 0 # desde donde que pagina empezar
#     }

#     response = requests.get(URL, params=params)
#     data = response.json()

#     print(
#         f"Solicitado: {limit:,} | "
#         f"Devuelto: {len(data.get('records', [])):,} | "
#         f"HTTP: {response.status_code}"
#     )

# %%
# params = {
#     "resource_id": "d45f660d-6d14-438e-9d91-300084c9b85f",
#     "limit": 32_000,
#     "offset": 0
# }

# response = requests.get(URL, params=params)
# data = response.json()

# print("HTTP:", response.status_code)
# print("Solicitados:", 32_000)
# print("Devueltos:", len(data["records"]))
# print("Total:", data["result"]["include_total"])
# print("Next:", data.get("next"))

# %%
# LIMIT = 32_000

# for offset in [0, 32_000, 64_000]:

#     params = {
#         "resource_id": "d45f660d-6d14-438e-9d91-300084c9b85f",
#         "limit": LIMIT,
#         "offset": offset
#     }

#     response = requests.get(URL, params=params)

#     response.raise_for_status()

#     data = response.json()

#     records = data["records"]

#     print(
#         f"Offset: {offset:,} | "
#         f"Registros: {len(records):,}"
#     )

# %%
# URL = "https://api.datosabiertos.mef.gob.pe/DatosAbiertos/v1/datastore_search"

# RESOURCE_ID = "d45f660d-6d14-438e-9d91-300084c9b85f"
# LIMIT = 32_000

# todos_los_records = []

# offset = 0

# while True:

#     params = {
#         "resource_id": RESOURCE_ID,
#         "limit": LIMIT,
#         "offset": offset
#     }

#     response = requests.get(URL, params=params)
#     response.raise_for_status()

#     data = response.json()

#     records = data["records"]

#     todos_los_records.extend(records)

#     print(
#         f"Offset: {offset:,} | "
#         f"Descargados: {len(todos_los_records):,}"
#     )

#     # Si llegaron menos registros que LIMIT,
#     # significa que llegamos al final.
#     if len(records) < LIMIT:
#         break

#     offset += LIMIT


# print(f"\nTotal descargado: {len(todos_los_records):,}")

# df = pl.DataFrame(todos_los_records)

# print(f"Filas: {df.height:,}")
# print(f"Columnas: {df.width}")

# %%
# import requests
# import polars as pl
# import pyarrow.parquet as pq


# URL = "https://api.datosabiertos.mef.gob.pe/DatosAbiertos/v1/datastore_search"

# RESOURCE_ID = "d45f660d-6d14-438e-9d91-300084c9b85f"

# LIMIT = 32_000

# OUTPUT = "mef_2026.parquet"


# writer = None
# columnas = None

# offset = 0
# pagina = 1


# while True:

#     params = {
#         "resource_id": RESOURCE_ID,
#         "limit": LIMIT,
#         "offset": offset
#     }

#     response = requests.get(URL, params=params)
#     response.raise_for_status()

#     data = response.json()
#     records = data["records"]

#     if not records:
#         break

#     # API → Polars
#     df = pl.DataFrame(records)

#     # Guardamos el orden de columnas de la primera página
#     if columnas is None:
#         columnas = df.columns

#     # Forzamos el mismo orden en todas las páginas
#     df = df.select(columnas)

#     print(
#         f"Página {pagina}/{MAX_PAGINAS} | "
#         f"Offset: {offset:,} | "
#         f"Registros: {df.height:,}"
#     )

#     # Polars → Arrow
#     table = df.to_arrow()

#     # Crear ParquetWriter solamente una vez
#     if writer is None:

#         writer = pq.ParquetWriter(
#             OUTPUT,
#             table.schema,
#             compression="zstd"
#         )

#     # Agregar página al Parquet
#     writer.write_table(table)

#     # Liberar memoria
#     del table
#     del df
#     del records
#     del data

#     offset += LIMIT
#     pagina += 1


# # Cerrar el archivo
# if writer is not None:
#     writer.close()


# print()
# print("Descarga de prueba completada.")

# %%
# import polars as pl

# df = pl.read_parquet("mef_2026.parquet")

# print("Filas:", df.height)
# print("Columnas:", df.width)

# print("\nColumnas:")
# print(df.columns)

# %%
# df = pl.read_parquet("mef_2026.parquet")

# columnas_numericas = [
#     "ANO_EJE",
#     "MES_EJE",
#     "MONTO_PIA",
#     "MONTO_PIM",
#     "MONTO_CERTIFICADO",
#     "MONTO_COMPROMETIDO",
#     "MONTO_COMPROMETIDO_ANUAL",
#     "MONTO_DEVENGADO",
#     "MONTO_GIRADO",
# ]

# for columna in columnas_numericas:
#     print(f"\n{'=' * 60}")
#     print(columna)
#     print(df.select(pl.col(columna).unique().head(10)))

# %%
# df = pl.read_parquet("mef_2026.parquet")

# columnas_int = [
#     "ANO_EJE",
#     "MES_EJE",
# ]

# columnas_float = [
#     "MONTO_PIA",
#     "MONTO_PIM",
#     "MONTO_CERTIFICADO",
#     "MONTO_COMPROMETIDO",
#     "MONTO_COMPROMETIDO_ANUAL",
#     "MONTO_DEVENGADO",
#     "MONTO_GIRADO",
# ]

# df_test = df.select(
#     [
#         pl.col(c).cast(pl.Int64).alias(c)
#         for c in columnas_int
#     ]
#     +
#     [
#         pl.col(c).cast(pl.Float64).alias(c)
#         for c in columnas_float
#     ]
# )

# print(df_test.schema)
# print()
# print(df_test.head())

# %%
# df_clean = df.with_columns(
#     [
#         pl.col(c).cast(pl.Int64)
#         for c in columnas_int
#     ]
#     +
#     [
#         pl.col(c).cast(pl.Float64)
#         for c in columnas_float
#     ]
# )

# df_clean.write_parquet(
#     "mef_2026_clean.parquet",
#     compression="zstd"
# )

# print("Archivo Silver creado correctamente.")
# print(f"Filas: {df_clean.height:,}")
# print(f"Columnas: {df_clean.width}")

# print("\nSchema:")
# print(df_clean.schema)

# %%
# df = pl.read_parquet("mef_2026.parquet")

# print("Filas:", df.height)
# print("Columnas:", df.width)

# print("\nSchema:")
# print(df.schema)

# %%
df = pd.read_csv('../data/raw/2026-Gasto-Mensual.csv',
                dtype = {
                    'SECTOR'        :   'string',
                    'PLIEGO'        :   'string',
                    'TIPO_RECURSO'  :   'string'
                })
df.head(2)
# Out:
#    ANO_EJE  MES_EJE NIVEL_GOBIERNO NIVEL_GOBIERNO_NOMBRE SECTOR  \
# 0     2026        8              R  GOBIERNOS REGIONALES     99
# 1     2026        8              R  GOBIERNOS REGIONALES     99
#
#           SECTOR_NOMBRE PLIEGO  \
# 0  GOBIERNOS REGIONALES    440
# 1  GOBIERNOS REGIONALES    440
#
#                                     PLIEGO_NOMBRE  SEC_EJEC  EJECUTORA  ...  \
# 0  GOBIERNO REGIONAL DEL DEPARTAMENTO DE AMAZONAS       721          1  ...
# 1  GOBIERNO REGIONAL DEL DEPARTAMENTO DE AMAZONAS       725        400  ...
#
#                                    ESPECIFICA_NOMBRE  ESPECIFICA_DET  \
# 0  LOCACIÓN DE SERVICIOS REALIZADOS POR PERSONA N...               1
# 1  ADQUISICION DE EQUIPOS INFORMATICOS Y DE COMUN...               1
#
#                                ESPECIFICA_DET_NOMBRE  MONTO_PIA MONTO_PIM  \
# 0  LOCACIÓN DE SERVICIOS REALIZADOS POR PERSONA N...          0         0
# 1              EQUIPOS COMPUTACIONALES Y PERIFERICOS          0         0
#
#    MONTO_CERTIFICADO MONTO_COMPROMETIDO_ANUAL  MONTO_COMPROMETIDO  \
# 0             2500.0                   2500.0                0.00
# 1                0.0                      0.0             3160.68
#
#    MONTO_DEVENGADO MONTO_GIRADO
# 0             0.00         0.00
# 1          8426.23      8426.23
#
# [2 rows x 63 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7689615 entries, 0 to 7689614
# Data columns (total 63 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   ANO_EJE                        int64
#  1   MES_EJE                        int64
#  2   NIVEL_GOBIERNO                 str
#  3   NIVEL_GOBIERNO_NOMBRE          str
#  4   SECTOR                         string
#  5   SECTOR_NOMBRE                  str
#  6   PLIEGO                         string
#  7   PLIEGO_NOMBRE                  str
#  8   SEC_EJEC                       int64
#  9   EJECUTORA                      int64
#  10  EJECUTORA_NOMBRE               str
#  11  DEPARTAMENTO_EJECUTORA         int64
#  12  DEPARTAMENTO_EJECUTORA_NOMBRE  str
#  13  PROVINCIA_EJECUTORA            int64
#  14  PROVINCIA_EJECUTORA_NOMBRE     str
#  15  DISTRITO_EJECUTORA             int64
#  16  DISTRITO_EJECUTORA_NOMBRE      str
#  17  SEC_FUNC                       int64
#  18  PROGRAMA_PPTO                  int64
#  19  PROGRAMA_PPTO_NOMBRE           str
#  20  TIPO_ACT_PROY                  int64
#  21  TIPO_ACT_PROY_NOMBRE           str
#  22  PRODUCTO_PROYECTO              int64
#  23  PRODUCTO_PROYECTO_NOMBRE       str
#  24  ACTIVIDAD_ACCION_OBRA          int64
#  25  ACTIVIDAD_ACCION_OBRA_NOMBRE   str
#  26  FUNCION                        int64
#  27  FUNCION_NOMBRE                 str
#  28  DIVISION_FUNCIONAL             int64
#  29  DIVISION_FUNCIONAL_NOMBRE      str
#  30  GRUPO_FUNCIONAL                int64
#  31  GRUPO_FUNCIONAL_NOMBRE         str
#  32  META                           int64
#  33  FINALIDAD                      int64
#  34  META_NOMBRE                    str
#  35  DEPARTAMENTO_META              int64
#  36  DEPARTAMENTO_META_NOMBRE       str
#  37  FUENTE_FINANCIAMIENTO          int64
#  38  FUENTE_FINANCIAMIENTO_NOMBRE   str
#  39  RUBRO                          int64
#  40  RUBRO_NOMBRE                   str
#  41  TIPO_RECURSO                   string
#  42  TIPO_RECURSO_NOMBRE            str
#  43  CATEGORIA_GASTO                int64
#  44  CATEGORIA_GASTO_NOMBRE         str
#  45  TIPO_TRANSACCION               int64
#  46  GENERICA                       int64
#  47  GENERICA_NOMBRE                str
#  48  SUBGENERICA                    int64
#  49  SUBGENERICA_NOMBRE             str
#  50  SUBGENERICA_DET                int64
#  51  SUBGENERICA_DET_NOMBRE         str
#  52  ESPECIFICA                     int64
#  53  ESPECIFICA_NOMBRE              str
#  54  ESPECIFICA_DET                 int64
#  55  ESPECIFICA_DET_NOMBRE          str
#  56  MONTO_PIA                      int64
#  57  MONTO_PIM                      int64
#  58  MONTO_CERTIFICADO              float64
#  59  MONTO_COMPROMETIDO_ANUAL       float64
#  60  MONTO_COMPROMETIDO             float64
#  61  MONTO_DEVENGADO                float64
#  62  MONTO_GIRADO                   float64
# dtypes: float64(5), int64(29), str(26), string(3)
# memory usage: 8.1 GB
# None

# %%
print(df.isnull().sum())
# Out:
# ANO_EJE                     0
# MES_EJE                     0
# NIVEL_GOBIERNO              0
# NIVEL_GOBIERNO_NOMBRE       0
# SECTOR                      0
#                            ..
# MONTO_CERTIFICADO           0
# MONTO_COMPROMETIDO_ANUAL    0
# MONTO_COMPROMETIDO          0
# MONTO_DEVENGADO             0
# MONTO_GIRADO                0
# Length: 63, dtype: int64

# %%
# COMPRENSIÓN DE LAS VARIABLES

# print(df.NIVEL_GOBIERNO_NOMBRE.unique())
# print(df.SEC_EJEC.unique())
# print(df.EJECUTORA.unique())
# print(df.EJECUTORA_NOMBRE.unique())
# print(df.DEPARTAMENTO_EJECUTORA_NOMBRE.unique())
# print(df.PROVINCIA_EJECUTORA_NOMBRE.unique())
# print(df.DISTRITO_EJECUTORA_NOMBRE.unique())
# print(df.PROGRAMA_PPTO_NOMBRE.unique())
# print(df.TIPO_ACT_PROY_NOMBRE.unique())
# print(df.PRODUCTO_PROYECTO_NOMBRE.unique())
# print(df.GENERICA_NOMBRE.unique())
# print(df.SUBGENERICA_NOMBRE.unique())
# print(df.ESPECIFICA_NOMBRE.unique())
# print(df.FUNCION_NOMBRE.unique())
# print(df.PROGRAMA_PPTO_NOMBRE.unique())
# print(df.CATEGORIA_GASTO_NOMBRE.unique())
# print(df.TIPO_ACT_PROY_NOMBRE.unique())
# print(df.GENERICA_NOMBRE.unique())

# %%
df[['MONTO_PIA', 'MONTO_PIM', 'MONTO_CERTIFICADO', 'MONTO_COMPROMETIDO_ANUAL', 'MONTO_COMPROMETIDO', 'MONTO_DEVENGADO', 'MONTO_GIRADO']].describe()
# Out:
#           MONTO_PIA     MONTO_PIM  MONTO_CERTIFICADO  \
# count  7.689615e+06  7.689615e+06       7.689615e+06
# mean   3.349474e+04  3.729521e+04       3.294292e+04
# std    5.147751e+06  5.079756e+06       5.018697e+06
# min    0.000000e+00 -8.248440e+05      -1.140409e+09
# 25%    0.000000e+00  0.000000e+00       0.000000e+00
# 50%    0.000000e+00  0.000000e+00       0.000000e+00
# 75%    0.000000e+00  0.000000e+00       6.000000e+02
# max    1.078797e+10  1.078797e+10       1.078790e+10
#
#        MONTO_COMPROMETIDO_ANUAL  MONTO_COMPROMETIDO  MONTO_DEVENGADO  \
# count              7.689615e+06        7.689615e+06     7.689615e+06
# mean               3.036768e+04        2.456908e+04     2.272841e+04
# std                5.002588e+06        3.329093e+06     3.360266e+06
# min               -1.000462e+09        0.000000e+00    -8.937874e+07
# 25%                0.000000e+00        0.000000e+00     0.000000e+00
# 50%                0.000000e+00        0.000000e+00     0.000000e+00
# 75%                7.800000e+02        2.389230e+03     2.412300e+03
# max                1.078790e+10        6.221093e+09     6.273908e+09
#
#        MONTO_GIRADO
# count  7.689615e+06
# mean   2.228742e+04
# std    3.331796e+06
# min   -1.588818e+09
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.285500e+03
# max    6.273908e+09

# %%
df[df['MONTO_PIM'] == -1.165660e+05]
# Out:
#          ANO_EJE  MES_EJE NIVEL_GOBIERNO NIVEL_GOBIERNO_NOMBRE SECTOR  \
# 4990104     2026        0              M     GOBIERNOS LOCALES
#
#         SECTOR_NOMBRE PLIEGO PLIEGO_NOMBRE  SEC_EJEC  EJECUTORA  ...  \
# 4990104                                       300041      10402  ...
#
#                                          ESPECIFICA_NOMBRE  ESPECIFICA_DET  \
# 4990104  SERVICIOS DE CONSULTORIAS Y SIMILARES DESARROL...              99
#
#              ESPECIFICA_DET_NOMBRE  MONTO_PIA MONTO_PIM  MONTO_CERTIFICADO  \
# 4990104  OTROS SERVICIOS SIMILARES       3500   -116566                0.0
#
#         MONTO_COMPROMETIDO_ANUAL  MONTO_COMPROMETIDO  MONTO_DEVENGADO  \
# 4990104                      0.0                 0.0              0.0
#
#         MONTO_GIRADO
# 4990104          0.0
#
# [1 rows x 63 columns]

# %%
df[df["MES_EJE"] == 0][
    ["MONTO_PIA", "MONTO_PIM", "MONTO_DEVENGADO"]
].describe()
# Out:
#           MONTO_PIA     MONTO_PIM  MONTO_DEVENGADO
# count  1.687689e+06  1.687689e+06        1687689.0
# mean   1.526120e+05  1.699281e+05              0.0
# std    1.098730e+07  1.084195e+07              0.0
# min    0.000000e+00 -8.248440e+05              0.0
# 25%    0.000000e+00  5.000000e+02              0.0
# 50%    8.400000e+02  4.000000e+03              0.0
# 75%    1.001200e+04  2.644300e+04              0.0
# max    1.078797e+10  1.078797e+10              0.0

# %%
df[df["MES_EJE"] == 0]["NIVEL_GOBIERNO_NOMBRE"].value_counts()
# Out:
# NIVEL_GOBIERNO_NOMBRE
# GOBIERNOS LOCALES       920318
# GOBIERNOS REGIONALES    399276
# GOBIERNO NACIONAL       368095
# Name: count, dtype: int64

# %%
df['NIVEL_GOBIERNO_NOMBRE'].value_counts()
# Out:
# NIVEL_GOBIERNO_NOMBRE
# GOBIERNOS LOCALES       4094928
# GOBIERNOS REGIONALES    1804835
# GOBIERNO NACIONAL       1789852
# Name: count, dtype: int64

# %%
df['TIPO_ACT_PROY_NOMBRE'].value_counts(dropna=False)
# Out:
# TIPO_ACT_PROY_NOMBRE
# ACTIVIDAD    6879582
# PROYECTO      810033
# Name: count, dtype: int64

# %% [markdown]
# Filtramos por GOBIERNOS LOCALES, PROYECTO Y GASTO CAPITAL, para identificar las inversiones públicas.

# %%
proyectos_locales = df[(df['NIVEL_GOBIERNO_NOMBRE'] == 'GOBIERNOS LOCALES') &
                (df['TIPO_ACT_PROY_NOMBRE'] == 'PROYECTO') & 
                (df['CATEGORIA_GASTO_NOMBRE'] == 'GASTO DE CAPITAL')]

# %%
num_proyectos = (proyectos_locales
                .groupby(['DEPARTAMENTO_EJECUTORA_NOMBRE','PROVINCIA_EJECUTORA_NOMBRE', 'DISTRITO_EJECUTORA_NOMBRE','FUNCION_NOMBRE', 'PRODUCTO_PROYECTO_NOMBRE'])['PRODUCTO_PROYECTO']
                .nunique()
                .reset_index()
                .sort_values(by=['DEPARTAMENTO_EJECUTORA_NOMBRE','PRODUCTO_PROYECTO'], ascending=False))


num_proyectos[num_proyectos['DISTRITO_EJECUTORA_NOMBRE'] == 'HUANCAYO']
# Out:
#       DEPARTAMENTO_EJECUTORA_NOMBRE PROVINCIA_EJECUTORA_NOMBRE  \
# 28674                         JUNIN                   HUANCAYO
# 28675                         JUNIN                   HUANCAYO
# 28676                         JUNIN                   HUANCAYO
# 28677                         JUNIN                   HUANCAYO
# 28678                         JUNIN                   HUANCAYO
# ...                             ...                        ...
# 28752                         JUNIN                   HUANCAYO
# 28753                         JUNIN                   HUANCAYO
# 28754                         JUNIN                   HUANCAYO
# 28755                         JUNIN                   HUANCAYO
# 28756                         JUNIN                   HUANCAYO
#
#       DISTRITO_EJECUTORA_NOMBRE                FUNCION_NOMBRE  \
# 28674                  HUANCAYO                      AMBIENTE
# 28675                  HUANCAYO                      AMBIENTE
# 28676                  HUANCAYO                      AMBIENTE
# 28677                  HUANCAYO             CULTURA Y DEPORTE
# 28678                  HUANCAYO             CULTURA Y DEPORTE
# ...                         ...                           ...
# 28752                  HUANCAYO  VIVIENDA Y DESARROLLO URBANO
# 28753                  HUANCAYO  VIVIENDA Y DESARROLLO URBANO
# 28754                  HUANCAYO  VIVIENDA Y DESARROLLO URBANO
# 28755                  HUANCAYO  VIVIENDA Y DESARROLLO URBANO
# 28756                  HUANCAYO  VIVIENDA Y DESARROLLO URBANO
#
#                                 PRODUCTO_PROYECTO_NOMBRE  PRODUCTO_PROYECTO
# 28674  CREACION DEL PARQUE ZONAL COTO COTO DISTRITO D...                  1
# 28675                          ESTUDIOS DE PRE-INVERSION                  1
# 28676  MEJORAMIENTO DEL SERVICIOS DE ESPACIOS PUBLICO...                  1
# 28677  CREACION DEL CENTRO RECREACIONAL POLIDEPORTIVO...                  1
# 28678  CREACION DEL SERVICIO DE PRACTICA DEPORTIVA Y/...                  1
# ...                                                  ...                ...
# 28752  MEJORAMIENTO DE LOS SERVICIOS DE ESPACIOS PUBL...                  1
# 28753  MEJORAMIENTO DE LOS SERVICIOS PUBLICOS DE INTE...                  1
# 28754  MEJORAMIENTO DEL SERVICIOS DE ESPACIOS PUBLICO...                  1
# 28755  MEJORAMIENTO, AMPLIACION DEL COMPLEJO DEPORTIV...                  1
# 28756  REPARACION DE SERVICIOS HIGIENICOS Y/O VESTIDO...                  1
#
# [83 rows x 6 columns]

# %%
proyectos_locales.groupby('FUNCION_NOMBRE')['PRODUCTO_PROYECTO'].nunique().sort_values(ascending=False)
# Out:
# FUNCION_NOMBRE
# TRANSPORTE                                         11254
# SANEAMIENTO                                         5508
# CULTURA Y DEPORTE                                   5415
# AGROPECUARIA                                        4369
# EDUCACION                                           4309
# PLANEAMIENTO, GESTION Y RESERVA DE CONTINGENCIA     3921
# VIVIENDA Y DESARROLLO URBANO                        3186
# ORDEN PUBLICO Y SEGURIDAD                           1158
# AMBIENTE                                            1054
# SALUD                                                988
# ENERGIA                                              668
# PROTECCION SOCIAL                                    521
# TURISMO                                              390
# COMERCIO                                             294
# INDUSTRIA                                            288
# COMUNICACIONES                                        83
# PESCA                                                 41
# TRABAJO                                               38
# MINERIA                                               12
# PREVISION SOCIAL                                       4
# Name: PRODUCTO_PROYECTO, dtype: int64

# %% [markdown]
# ### Porcentaje de ejecución de proyectos publicos de la provicina de Huancayo y sus distritos

# %%
# PROYECTOS HUANCAYO PROVICIA Y SUS DISTRITOS MUNICIPALES
hyo_provincia = (proyectos_locales
        .groupby(['DEPARTAMENTO_EJECUTORA_NOMBRE','PROVINCIA_EJECUTORA_NOMBRE', 'EJECUTORA_NOMBRE'])
                [['MONTO_PIA','MONTO_PIM', 'MONTO_DEVENGADO']]
        .sum()
        .reset_index()
        .sort_values('MONTO_PIM', ascending=False))

hyo_provincia['EJECUCION_%'] = (hyo_provincia['MONTO_DEVENGADO'] / hyo_provincia['MONTO_PIM'])  * 100

hyo_provincia = (hyo_provincia[(hyo_provincia['DEPARTAMENTO_EJECUTORA_NOMBRE'] == 'JUNIN') & 
                (hyo_provincia['PROVINCIA_EJECUTORA_NOMBRE'] == 'HUANCAYO')]
                .sort_values('EJECUCION_%', ascending=False))

hyo_provincia.to_csv('hyo_provincia.csv', index=False)

hyo_provincia
# Out:
#      DEPARTAMENTO_EJECUTORA_NOMBRE PROVINCIA_EJECUTORA_NOMBRE  \
# 1077                         JUNIN                   HUANCAYO
# 1071                         JUNIN                   HUANCAYO
# 1088                         JUNIN                   HUANCAYO
# 1075                         JUNIN                   HUANCAYO
# 1093                         JUNIN                   HUANCAYO
# 1090                         JUNIN                   HUANCAYO
# 1079                         JUNIN                   HUANCAYO
# 1084                         JUNIN                   HUANCAYO
# 1085                         JUNIN                   HUANCAYO
# 1094                         JUNIN                   HUANCAYO
# 1096                         JUNIN                   HUANCAYO
# 1082                         JUNIN                   HUANCAYO
# 1092                         JUNIN                   HUANCAYO
# 1074                         JUNIN                   HUANCAYO
# 1078                         JUNIN                   HUANCAYO
# 1091                         JUNIN                   HUANCAYO
# 1080                         JUNIN                   HUANCAYO
# 1073                         JUNIN                   HUANCAYO
# 1098                         JUNIN                   HUANCAYO
# 1089                         JUNIN                   HUANCAYO
# 1086                         JUNIN                   HUANCAYO
# 1072                         JUNIN                   HUANCAYO
# 1087                         JUNIN                   HUANCAYO
# 1076                         JUNIN                   HUANCAYO
# 1095                         JUNIN                   HUANCAYO
# 1081                         JUNIN                   HUANCAYO
# 1083                         JUNIN                   HUANCAYO
# 1097                         JUNIN                   HUANCAYO
#
#                                        EJECUTORA_NOMBRE  MONTO_PIA  MONTO_PIM  \
# 1077                   MUNICIPALIDAD DISTRITAL DE COLCA     998679    1195230
# 1071          MUNICIPALIDAD DISTRITAL DE CARHUACALLANGA     593885    2504679
# 1088                  MUNICIPALIDAD DISTRITAL DE PUCARA    1571933    7410848
# 1075            MUNICIPALIDAD DISTRITAL DE CHONGOS ALTO     556732    6389426
# 1093  MUNICIPALIDAD DISTRITAL DE SANTO DOMINGO DE AC...    2741459    6045623
# 1090                 MUNICIPALIDAD DISTRITAL DE QUILCAS     393492    4094219
# 1079                MUNICIPALIDAD DISTRITAL DE EL TAMBO    9918676   30239177
# 1084              MUNICIPALIDAD DISTRITAL DE HUAYUCACHI   11262017   17807841
# 1085                 MUNICIPALIDAD DISTRITAL DE INGENIO    1271998    3017993
# 1094              MUNICIPALIDAD DISTRITAL DE SAPALLANGA    2637496   12840693
# 1096                  MUNICIPALIDAD DISTRITAL DE SICAYA    1917805    7036233
# 1082                 MUNICIPALIDAD DISTRITAL DE HUANCAN   12750031   24895206
# 1092   MUNICIPALIDAD DISTRITAL DE SAN JERONIMO DE TUNAN     521098    3548936
# 1074                  MUNICIPALIDAD DISTRITAL DE CHILCA    3599168   30303130
# 1078                MUNICIPALIDAD DISTRITAL DE CULLHUAS     101239     792021
# 1091             MUNICIPALIDAD DISTRITAL DE SAN AGUSTIN     936621    8681175
# 1080            MUNICIPALIDAD DISTRITAL DE HUACRAPUQUIO    1704722    2268958
# 1073                 MUNICIPALIDAD DISTRITAL DE CHICCHE      22318     446734
# 1098               MUNICIPALIDAD PROVINCIAL DE HUANCAYO   24119661   71312006
# 1089                MUNICIPALIDAD DISTRITAL DE QUICHUAY     135306     453655
# 1086             MUNICIPALIDAD DISTRITAL DE PARIAHUANCA    1905536    5174138
# 1072              MUNICIPALIDAD DISTRITAL DE CHACAPAMPA     109035    1600496
# 1087               MUNICIPALIDAD DISTRITAL DE PILCOMAYO    2300000    9577598
# 1076                 MUNICIPALIDAD DISTRITAL DE CHUPURO     205877    2397281
# 1095                    MUNICIPALIDAD DISTRITAL DE SAÑO     544749    2678706
# 1081                MUNICIPALIDAD DISTRITAL DE HUALHUAS     345269    3900558
# 1083             MUNICIPALIDAD DISTRITAL DE HUASICANCHA    3945531    9428239
# 1097                  MUNICIPALIDAD DISTRITAL DE VIQUES     134671     586334
#
#       MONTO_DEVENGADO  EJECUCION_%
# 1077       1070079.36    89.529158
# 1071       1960296.55    78.265381
# 1088       5189021.98    70.019274
# 1075       4084922.08    63.932536
# 1093       3130339.96    51.778617
# 1090       1947739.43    47.572918
# 1079      13538025.10    44.769820
# 1084       7895257.65    44.335850
# 1085       1213293.50    40.201998
# 1094       5017557.23    39.075440
# 1096       2663344.08    37.851846
# 1082       9006957.33    36.179485
# 1092       1275232.27    35.932805
# 1074      10075354.31    33.248560
# 1078        259441.67    32.756918
# 1091       2826951.72    32.564160
# 1080        638734.50    28.151006
# 1073        121133.60    27.115375
# 1098      19007833.29    26.654464
# 1089        119246.37    26.285695
# 1086       1329942.93    25.703662
# 1072        353901.75    22.112005
# 1087       1740619.96    18.173867
# 1076        423846.18    17.680288
# 1095        379966.37    14.184699
# 1081        342667.04     8.785077
# 1083        544343.32     5.773542
# 1097             0.00     0.000000

# %%
import plotly.express as px

fig = px.bar(
    hyo_provincia,
    x = "EJECUCION_%",
    y = "EJECUTORA_NOMBRE",
    # title="Presupuesto ejecutado por distrito",

    text = "EJECUCION_%",
    # text_auto=".2f",
    # #hover_data = ["MONTO_DEVENGADO", "EJECUCION_%"],
    # labels = {
    #     "EJECUCION_%": "PORCENTAJE EJECUTADO",
    #     "EJECUTORA_NOMBRE":"MUNICIPALIDAD"
    # },
    # color_continuous_scale="Viridis"

)

fig.update_layout(
    title="PORCENTAJE DE EJECUCIÓN POR DISTRITO" ,title_font_size=20,
    template="plotly_dark"
)

fig.update_traces(
    textposition = "outside",
    hovertemplate="%{y}: %{x:.1f}%",
    texttemplate="%{text:.1f}",

    marker_line_width=1

)

fig.update_xaxes(
    title=" ",
    ticksuffix="%"
)

fig.update_yaxes(
    title = " "
)

fig.show()

# %%
presupuesto = (proyectos_locales[proyectos_locales['MES_EJE'] == 0]
                .groupby([
                        'ANO_EJE',
                        'DEPARTAMENTO_EJECUTORA_NOMBRE',
                        'PROVINCIA_EJECUTORA_NOMBRE', 
                        'DISTRITO_EJECUTORA_NOMBRE'])
                [['MONTO_PIA','MONTO_PIM']]
                .sum()
                .reset_index())
presupuesto.head()

presupuesto.to_parquet('../data/processed/presupuesto.parquet', index=False)

# %%
presupuesto[presupuesto['DISTRITO_EJECUTORA_NOMBRE'] == 'EL TAMBO']
# Out:
#       ANO_EJE DEPARTAMENTO_EJECUTORA_NOMBRE PROVINCIA_EJECUTORA_NOMBRE  \
# 1078     2026                         JUNIN                   HUANCAYO
#
#      DISTRITO_EJECUTORA_NOMBRE  MONTO_PIA  MONTO_PIM
# 1078                  EL TAMBO    9918676   30239177

# %%
ejecucion_mensual = (proyectos_locales[proyectos_locales['MES_EJE']
                .between(1,12)]
                .groupby([
                        'ANO_EJE'                       ,
                        'MES_EJE'                       ,
                        'DEPARTAMENTO_EJECUTORA_NOMBRE' ,
                        'PROVINCIA_EJECUTORA_NOMBRE'    ,
                        'DISTRITO_EJECUTORA_NOMBRE'     ,
                        'PRODUCTO_PROYECTO_NOMBRE'      ,
                        'FUNCION_NOMBRE'                ,
                ])[['MONTO_DEVENGADO']]
                .sum()
                .reset_index())

ejecucion_mensual['FECHA'] = pd.to_datetime(
    ejecucion_mensual['ANO_EJE'].astype(str)
    + '-'
    + ejecucion_mensual['MES_EJE'].astype(str)
    + '-01'
)

ejecucion_mensual = ejecucion_mensual.sort_values(
    ['ANO_EJE', 'DEPARTAMENTO_EJECUTORA_NOMBRE',
     'PROVINCIA_EJECUTORA_NOMBRE', 'DISTRITO_EJECUTORA_NOMBRE',
      'FECHA'
      ]
)

ejecucion_mensual['MONTO_DEVENGADO_ACUMULADO'] = (
    ejecucion_mensual
    .groupby([
        'ANO_EJE',
        'DEPARTAMENTO_EJECUTORA_NOMBRE',
        'PROVINCIA_EJECUTORA_NOMBRE',
        'DISTRITO_EJECUTORA_NOMBRE'
    ])['MONTO_DEVENGADO']
    .cumsum()
)

ejecucion_mensual.to_parquet('../data/processed/ejecucion_mensual.parquet', index=False)

# %%
producto_projecto = ejecucion_mensual.groupby(['MES_EJE','PROVINCIA_EJECUTORA_NOMBRE','DISTRITO_EJECUTORA_NOMBRE', 'PRODUCTO_PROYECTO_NOMBRE','FUNCION_NOMBRE'])['MONTO_DEVENGADO'].sum().reset_index()

hyo_prod = producto_projecto[(producto_projecto['DISTRITO_EJECUTORA_NOMBRE'] == 'EL TAMBO') & 
                          (producto_projecto['MES_EJE'] == 7)     ]

hyo_prod['FUNCION_NOMBRE'].value_counts()
# Out:
# FUNCION_NOMBRE
# TRANSPORTE           18
# SANEAMIENTO          14
# EDUCACION             2
# CULTURA Y DEPORTE     1
# Name: count, dtype: int64

# %%
tambo = ejecucion_mensual[ejecucion_mensual["DISTRITO_EJECUTORA_NOMBRE"] == "EL TAMBO"].sort_values("FECHA")
import plotly.express as px

fig = px.line(
    tambo,
    x="FECHA", 
    y="MONTO_DEVENGADO_ACUMULADO",
    title='MONTO ACUMULADO',
    markers=True,
    )

fig.show()

# %%
# presupuesto.loc[presupuesto["DEPARTAMENTO_EJECUTORA_NOMBRE"] == 'JUNIN', 'PROVINCIA_EJECUTORA_NOMBRE']

# %%
os.listdir('../data/processed/')
# Out:
# ['presupuesto.parquet', 'ejecucion_mensual.parquet']

# %%
# m6 = proyectos_hyo[proyectos_hyo['MES_EJE'] <= 6].groupby(['EJECUTORA_NOMBRE'])[['MONTO_PIA','MONTO_PIM','MONTO_DEVENGADO']].sum().reset_index()
# m6['EJECUCION_%_6'] = (m6['MONTO_DEVENGADO'] / m6['MONTO_PIM'])  * 100

# m7 = proyectos_hyo[proyectos_hyo['MES_EJE'] <= 7].groupby(['EJECUTORA_NOMBRE'])[['MONTO_PIA','MONTO_PIM','MONTO_DEVENGADO']].sum().reset_index()
# m7['EJECUCION_%_7'] = (m7['MONTO_DEVENGADO'] / m7['MONTO_PIM'])  * 100

# variacion_hyo = m6.merge(m7, on=['EJECUTORA_NOMBRE', 'MONTO_PIA', 'MONTO_PIM'], how='left')
# variacion_hyo

# %% [markdown]
# ### Porcentaje de ejecución de proyectos por gobiernos regionales.

# %%
proyectos_regionales = df[(df['NIVEL_GOBIERNO_NOMBRE'] == 'GOBIERNOS REGIONALES') & 
                        (df['TIPO_ACT_PROY_NOMBRE'] == 'PROYECTO') & 
                        (df['CATEGORIA_GASTO_NOMBRE'] == 'GASTO DE CAPITAL')]


num_proyectos = (proyectos_regionales
                .groupby(['DEPARTAMENTO_EJECUTORA_NOMBRE', 'FUNCION_NOMBRE'])['PRODUCTO_PROYECTO']
                .nunique()
                .reset_index()
                .sort_values(by=['DEPARTAMENTO_EJECUTORA_NOMBRE','PRODUCTO_PROYECTO'], ascending=False))
                
num_proyectos[num_proyectos['DEPARTAMENTO_EJECUTORA_NOMBRE'] == 'JUNIN']
# Out:
#     DEPARTAMENTO_EJECUTORA_NOMBRE  \
# 143                         JUNIN
# 148                         JUNIN
# 147                         JUNIN
# 156                         JUNIN
# 154                         JUNIN
# 155                         JUNIN
# 152                         JUNIN
# 157                         JUNIN
# 151                         JUNIN
# 144                         JUNIN
# 150                         JUNIN
# 158                         JUNIN
# 153                         JUNIN
# 145                         JUNIN
# 146                         JUNIN
# 149                         JUNIN
#
#                                       FUNCION_NOMBRE  PRODUCTO_PROYECTO
# 143                                     AGROPECUARIA                233
# 148                                        INDUSTRIA                142
# 147                                        EDUCACION                133
# 156                                       TRANSPORTE                 81
# 154                                            SALUD                 48
# 155                                      SANEAMIENTO                 30
# 152  PLANEAMIENTO, GESTION Y RESERVA DE CONTINGENCIA                 26
# 157                                          TURISMO                 21
# 151                                            PESCA                 10
# 144                                         AMBIENTE                  8
# 150                        ORDEN PUBLICO Y SEGURIDAD                  6
# 158                     VIVIENDA Y DESARROLLO URBANO                  4
# 153                                PROTECCION SOCIAL                  3
# 145                                         COMERCIO                  1
# 146                                CULTURA Y DEPORTE                  1
# 149                                         JUSTICIA                  1

# %%
regional = (proyectos_regionales
            .groupby(['ANO_EJE','DEPARTAMENTO_EJECUTORA_NOMBRE'])[[ 'MONTO_PIA', "MONTO_PIM", "MONTO_DEVENGADO"]]
            .sum()
            .reset_index())

regional['EJECUCION_%'] = (regional['MONTO_DEVENGADO'] / regional['MONTO_PIM'])  * 100

regional = regional.sort_values(by='EJECUCION_%', ascending=False)

regional.to_csv('regional_ejecucion.csv', index=False)
regional
# Out:
#     ANO_EJE        DEPARTAMENTO_EJECUTORA_NOMBRE   MONTO_PIA   MONTO_PIM  \
# 10     2026                                JUNIN   935360978  1047878448
# 4      2026                             AYACUCHO   900000000   828577416
# 9      2026                                  ICA   447333116   527108637
# 14     2026                               LORETO   967959831  1082750983
# 0      2026                             AMAZONAS   421052022   481167990
# 3      2026                             AREQUIPA   640350532   912165529
# 22     2026                                TACNA   242465752   413724561
# 18     2026                                PIURA  1160117886  1200266520
# 24     2026                              UCAYALI   638776183   692061822
# 21     2026                           SAN MARTIN   633741904   610995609
# 16     2026                             MOQUEGUA   254596641   299773798
# 6      2026                                CUSCO   925142319  1207027052
# 15     2026                        MADRE DE DIOS   192137153   213736296
# 13     2026                                 LIMA   428477523   586670793
# 5      2026                            CAJAMARCA   682091188  1053028296
# 2      2026                             APURIMAC   319408894   519810467
# 12     2026                           LAMBAYEQUE   839385905   756925857
# 17     2026                                PASCO   537627067   862247255
# 20     2026                                 PUNO   797237434   983101884
# 7      2026                         HUANCAVELICA   244805255   297336845
# 8      2026                              HUANUCO   474818256   454773463
# 11     2026                          LA LIBERTAD   906843743   954489571
# 1      2026                               ANCASH   451433537   811659213
# 23     2026                               TUMBES   170840282   147442796
# 19     2026  PROVINCIA CONSTITUCIONAL DEL CALLAO   409704652   331506842
#
#     MONTO_DEVENGADO  EJECUCION_%
# 10     7.725463e+08    73.724798
# 4      6.003081e+08    72.450460
# 9      3.718356e+08    70.542502
# 14     7.473212e+08    69.020597
# 0      3.317478e+08    68.946363
# 3      6.251279e+08    68.532285
# 22     2.694239e+08    65.121551
# 18     7.594048e+08    63.269683
# 24     4.278807e+08    61.826942
# 21     3.748122e+08    61.344506
# 16     1.714926e+08    57.207349
# 6      6.817485e+08    56.481626
# 15     1.198807e+08    56.088128
# 13     3.258348e+08    55.539628
# 5      5.465960e+08    51.907058
# 2      2.675472e+08    51.470150
# 12     3.710488e+08    49.020501
# 17     3.745636e+08    43.440399
# 20     4.260201e+08    43.334278
# 7      1.215353e+08    40.874628
# 8      1.808093e+08    39.758100
# 11     3.667130e+08    38.419797
# 1      2.955906e+08    36.418063
# 23     4.921479e+07    33.378904
# 19     7.374989e+07    22.246868

# %%
top_10 = regional.head(5).copy()

fig, ax = plt.subplots(figsize=(11,5))

ax.barh(top_10['DEPARTAMENTO_EJECUTORA_NOMBRE'],
        top_10['EJECUCION_%'], color='#4B75FF')

ax.invert_yaxis()

ax.set_xlabel('EJECUCIÓN PRESUPUESTAL (%)')
ax.set_title('Ejecución presupuestal de Gobiernos Regionales - 2026', fontsize = 16)
ax.grid(True, alpha=0.3)

for i, valor in enumerate(top_10['EJECUCION_%']):
    ax.text(valor + 0.3,
            i,
            f'{valor:.1f}%',
            va='center')

plt.tight_layout()
plt.show()

fig.savefig(
    "ranking_gobiernos_regionales.png",
    dpi=300,
    bbox_inches="tight"
)

# %%
df_junin = proyectos_regionales[proyectos_regionales['DEPARTAMENTO_EJECUTORA_NOMBRE'] == 'JUNIN']

# %%
tipo_gastos = df_junin.groupby(['DEPARTAMENTO_EJECUTORA_NOMBRE','ANO_EJE', 'FUNCION_NOMBRE'])[['MONTO_PIA',"MONTO_PIM", "MONTO_DEVENGADO"]].sum().reset_index()

tipo_gastos['EJECUCION_%'] = (tipo_gastos['MONTO_DEVENGADO'] / tipo_gastos['MONTO_PIM'])  * 100

tipo_gastos = tipo_gastos.sort_values(by='MONTO_DEVENGADO', ascending=False)
tipo_gastos.to_csv('tipo_gastos_junin.csv', index=False)
tipo_gastos
# Out:
#    DEPARTAMENTO_EJECUTORA_NOMBRE  ANO_EJE  \
# 4                          JUNIN     2026
# 13                         JUNIN     2026
# 0                          JUNIN     2026
# 11                         JUNIN     2026
# 12                         JUNIN     2026
# 9                          JUNIN     2026
# 7                          JUNIN     2026
# 10                         JUNIN     2026
# 15                         JUNIN     2026
# 3                          JUNIN     2026
# 1                          JUNIN     2026
# 14                         JUNIN     2026
# 5                          JUNIN     2026
# 2                          JUNIN     2026
# 6                          JUNIN     2026
# 8                          JUNIN     2026
#
#                                      FUNCION_NOMBRE  MONTO_PIA  MONTO_PIM  \
# 4                                         EDUCACION  376244594  370616254
# 13                                       TRANSPORTE  273364462  299047390
# 0                                      AGROPECUARIA   18479604  102481634
# 11                                            SALUD  186056903  152042859
# 12                                      SANEAMIENTO   19993268   41973929
# 9   PLANEAMIENTO, GESTION Y RESERVA DE CONTINGENCIA   21335410   37785999
# 7                         ORDEN PUBLICO Y SEGURIDAD   21202351   13152221
# 10                                PROTECCION SOCIAL    6000000    6796062
# 15                     VIVIENDA Y DESARROLLO URBANO   12286729    7942535
# 3                                 CULTURA Y DEPORTE          0    4824810
# 1                                          AMBIENTE          0    3939112
# 14                                          TURISMO     397657    3611537
# 5                                         INDUSTRIA          0    1592156
# 2                                          COMERCIO          0     828050
# 6                                          JUSTICIA          0    1094356
# 8                                             PESCA          0     149544
#
#     MONTO_DEVENGADO  EJECUCION_%
# 4      3.014006e+08    81.324165
# 13     2.158416e+08    72.176377
# 0      8.903914e+07    86.883023
# 11     8.283044e+07    54.478348
# 12     3.144916e+07    74.925460
# 9      1.949692e+07    51.598267
# 7      1.063115e+07    80.831616
# 10     5.987752e+06    88.106197
# 15     4.815524e+06    60.629560
# 3      4.398554e+06    91.165322
# 1      2.455530e+06    62.337152
# 14     2.138682e+06    59.218062
# 5      9.863180e+05    61.948578
# 2      5.721945e+05    69.101443
# 6      4.924600e+05    44.999984
# 8      1.030000e+04     6.887605

# %%
top_5 = tipo_gastos.head(5).copy()
top_5["DEVENGADO_M"] = top_5["MONTO_DEVENGADO"] / 1_000_000
top_5["PIM_M"] = top_5["MONTO_PIM"] / 1_000_000
top_5['RESTO'] = top_5['PIM_M'] - top_5['DEVENGADO_M']
top_5.to_csv('tipo_gastos_junin.csv', index=False)

fig, ax = plt.subplots(figsize=(11,5))

ax.barh(top_5['FUNCION_NOMBRE'],
        top_5['DEVENGADO_M'], color='#4B75FF')

ax.invert_yaxis()

ax.set_xlabel('Monto devengado (millones de soles)')
ax.set_title('¿En qué se está gastando el dinero de Junín?', fontsize = 16)
ax.grid(True, alpha=0.3)

for i, valor in enumerate(top_5["DEVENGADO_M"]):
    ax.text(
        valor + 20,
        i,
        f"S/ {valor:,.1f} M",
        va="center",
        fontsize=10
    )

plt.tight_layout()
plt.show()
